# %%
from utils.tiny_cnn import fast_train_model, TinyCNN

fast_train_model(TinyCNN(), "TinyCNN", epochs=100)
# Out:
# 🚀 开始快速训练 TinyCNN...
# Epoch 1/50: Loss = 4.119, Train Acc = 6.55%, Test Acc = 12.80%
# Epoch 6/50: Loss = 3.397, Train Acc = 17.10%, Test Acc = 28.50%
# Epoch 11/50: Loss = 3.174, Train Acc = 21.60%, Test Acc = 31.50%
# Epoch 16/50: Loss = 2.994, Train Acc = 25.26%, Test Acc = 36.80%
# Epoch 21/50: Loss = 2.869, Train Acc = 27.67%, Test Acc = 37.75%
# Epoch 26/50: Loss = 2.774, Train Acc = 29.42%, Test Acc = 41.05%
# Epoch 31/50: Loss = 2.702, Train Acc = 31.09%, Test Acc = 41.90%
# Epoch 36/50: Loss = 2.649, Train Acc = 32.17%, Test Acc = 43.25%
# Epoch 41/50: Loss = 2.616, Train Acc = 32.80%, Test Acc = 43.65%
# Epoch 46/50: Loss = 2.587, Train Acc = 33.28%, Test Acc = 43.45%
# Epoch 50/50: Loss = 2.584, Train Acc = 33.37%, Test Acc = 43.90%
# 🎉 TinyCNN 训练完成! 最佳准确率: 43.90%
# (TinyCNN(
#    (features): Sequential(
#      (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch
from utils.tiny_cnn import fast_train_model, TinyCNN

# 接着训练看看是否收敛
model = TinyCNN()
model.load_state_dict(torch.load("../model_weights/TinyCNN_best.pth"))

fast_train_model(model, "TinyCNN", epochs=200)
# Out:
# 🚀 开始快速训练 TinyCNN...
#   0%|          | 1/200 [00:13<45:33, 13.74s/it]
# Epoch 1/200: Loss = 2.330, Train Acc = 38.52%, Test Acc = 50.35%
#   3%|▎         | 6/200 [01:09<39:54, 12.34s/it]
# Epoch 6/200: Loss = 2.285, Train Acc = 39.52%, Test Acc = 50.95%
#   6%|▌         | 11/200 [01:58<32:32, 10.33s/it]
# Epoch 11/200: Loss = 2.275, Train Acc = 39.62%, Test Acc = 52.30%
#   8%|▊         | 16/200 [02:40<28:58,  9.45s/it]
# Epoch 16/200: Loss = 2.265, Train Acc = 39.92%, Test Acc = 52.25%
#  10%|█         | 21/200 [03:23<27:54,  9.36s/it]
# Epoch 21/200: Loss = 2.260, Train Acc = 40.10%, Test Acc = 51.80%
#  13%|█▎        | 26/200 [04:07<27:02,  9.33s/it]
# Epoch 26/200: Loss = 2.256, Train Acc = 40.21%, Test Acc = 51.95%
#  16%|█▌        | 31/200 [04:50<26:21,  9.36s/it]
# Epoch 31/200: Loss = 2.246, Train Acc = 40.23%, Test Acc = 51.80%
#  18%|█▊        | 36/200 [05:35<27:05,  9.91s/it]
# Epoch 36/200: Loss = 2.238, Train Acc = 40.50%, Test Acc = 51.90%
# ...

# %%
from utils.res_net import ResNet20
from utils.tiny_cnn import fast_train_model, TinyCNN
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
teacher_model = ResNet20(num_classes=100).to(device)
teacher_model.load_state_dict(
    torch.load("../model_weights/student_vanilla_resnet20_best.pth")
)

student_model = TinyCNN()
student_model.load_state_dict(
    torch.load("../model_weights/TinyCNN_distilled_best_0.7_4.pth")
)

fast_train_model(
    student_model,
    "TinyCNN",
    use_distillation=True,
    teacher_model=teacher_model,
    epochs=100,
)
# Out:
# 🚀 开始快速训练 TinyCNN...
#   1%|          | 1/100 [00:14<24:19, 14.74s/it]
# Epoch 1/100: Loss = 5.576, Train Acc = 39.88%, Test Acc = 51.40%
#   6%|▌         | 6/100 [01:12<19:43, 12.59s/it]
# Epoch 6/100: Loss = 5.470, Train Acc = 39.56%, Test Acc = 50.25%
#  11%|█         | 11/100 [02:10<18:02, 12.16s/it]
# Epoch 11/100: Loss = 5.432, Train Acc = 39.37%, Test Acc = 50.25%
#  16%|█▌        | 16/100 [03:06<16:54, 12.08s/it]
# Epoch 16/100: Loss = 5.412, Train Acc = 39.35%, Test Acc = 50.60%
#  21%|██        | 21/100 [04:04<16:17, 12.37s/it]
# Epoch 21/100: Loss = 5.402, Train Acc = 39.14%, Test Acc = 50.95%
#  26%|██▌       | 26/100 [05:07<16:05, 13.05s/it]
# Epoch 26/100: Loss = 5.385, Train Acc = 39.12%, Test Acc = 50.90%
#  31%|███       | 31/100 [06:07<14:30, 12.61s/it]
# Epoch 31/100: Loss = 5.369, Train Acc = 39.14%, Test Acc = 50.60%
#  36%|███▌      | 36/100 [07:07<13:28, 12.64s/it]
# Epoch 36/100: Loss = 5.364, Train Acc = 38.96%, Test Acc = 51.20%
# ...

# %%
from utils.res_net import ResNet20
from utils.tiny_cnn import fast_train_model, TinyCNN
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
teacher_model = ResNet20(num_classes=100).to(device)
teacher_model.load_state_dict(
    torch.load("../model_weights/student_vanilla_resnet20_best.pth")
)

# 调参
for alpha in [0.3, 0.5, 0.7, 0.9]:
    for temperature in [2, 4, 8]:
        fast_train_model(
            TinyCNN(),
            "TinyCNN",
            use_distillation=True,
            teacher_model=teacher_model,
            alpha=alpha,
            temperature=temperature,
            epochs=200,
        )
# Out:
# 🚀 开始快速训练 TinyCNN...
#   0%|          | 1/200 [00:14<49:14, 14.85s/it]
# Epoch 1/200: Loss = 7.156, Train Acc = 2.89%, Test Acc = 6.30%
#   3%|▎         | 6/200 [01:11<39:31, 12.22s/it]
# Epoch 6/200: Loss = 5.798, Train Acc = 14.87%, Test Acc = 21.45%
#   6%|▌         | 11/200 [02:09<38:07, 12.11s/it]
# Epoch 11/200: Loss = 5.410, Train Acc = 19.29%, Test Acc = 26.50%
#   8%|▊         | 16/200 [03:06<37:06, 12.10s/it]
# Epoch 16/200: Loss = 5.206, Train Acc = 22.23%, Test Acc = 30.90%
#  10%|█         | 21/200 [04:03<36:00, 12.07s/it]
# Epoch 21/200: Loss = 5.073, Train Acc = 23.87%, Test Acc = 32.35%
#  13%|█▎        | 26/200 [05:04<36:55, 12.73s/it]
# Epoch 26/200: Loss = 5.001, Train Acc = 24.74%, Test Acc = 33.95%
#  16%|█▌        | 31/200 [06:03<34:55, 12.40s/it]
# Epoch 31/200: Loss = 4.910, Train Acc = 25.78%, Test Acc = 35.40%
#  18%|█▊        | 36/200 [07:00<33:11, 12.15s/it]
# Epoch 36/200: Loss = 4.844, Train Acc = 26.55%, Test Acc = 36.45%
# ...
